# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(3,3))
plt.imshow(img)

# %% [markdown]
# OPenCV and Matpliot lib expects
#
#
#
# *   OPEN CV - Blue Green Red
# *   Matplotlib - Red Green Blue

# %%
fixed_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(3,3))
plt.imshow(fixed_img)

# %%
gray_img = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/00-puppy.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(3,3))
plt.imshow(gray_img, cmap="gray")

# %%
reduced_image = cv2.resize(img,(0,0),img, 0.2,0.5)

# %%
plt.figure(figsize=(3,3))
plt.imshow(reduced_image, cmap="gray")

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/00-puppy.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1950x1300>
