# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
giraff = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/giraffes.jpg")
giraff = cv2.cvtColor(giraff, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(giraff)

# %%
ret, thresh1= cv2.threshold(giraff, 127, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh1)

# %%
giraff = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/giraffes.jpg",0)
ret, thresh1= cv2.threshold(giraff, 127, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh1, cmap = "gray")

# %%
giraff = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/giraffes.jpg")
giraff = cv2.cvtColor(giraff, cv2.COLOR_BGR2HSV)
plt.imshow(giraff)

# %%
kernel= np.ones(shape=(5,5), dtype= np.float32) / 25

# %%
giraff = cv2.imread("/content/drive/MyDrive/Computer-Vision-with-Python/DATA/giraffes.jpg")
giraff = cv2.cvtColor(giraff, cv2.COLOR_BGR2RGB)
plt.imshow(giraff)

# %%
result = cv2.filter2D(giraff, ddepth=-1,kernel=kernel)
plt.imshow(result)
